# %%
# %load_ext autoreload
# %autoreload 2

from helpers.fin_stats import TIME_PERIODS, run_stats
import helpers.plotting as plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Out:
# <div>                            <div id="fbc33b42-b787-4ad3-8a99-7d8717be6441" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbc33b42-b787-4ad3-8a99-7d8717be6441")) {                    Plotly.newPlot(                        "fbc33b42-b787-4ad3-8a99-7d8717be6441",                        [{"hovertemplate":"date=%{x}<br>return=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2010-01-04 00:00:00.000000","2010-01-05 00:00:00.000000","2010-01-06 00:00:00.000000","2010-01-07 00:00:00.000000","2010-01-08 00:00:00.000000","2010-01-11 00:00:00.000000","2010-01-12 00:00:00.000000","2010-01-13 00:00:00.000000","2010-01-14 00:00:00.000000","2010-01-1
# ...

# %%
# Out:
# {'cumulative_return': 2.904563926711234, 'ann_return': 0.10856896089216028, 'ann_volatility': 0.04819654871490125, 'ann_sharpe': 2.1630499375316035}
